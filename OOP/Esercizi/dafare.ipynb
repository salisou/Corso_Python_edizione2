# %% [markdown]
# #### Asia:
#  - Chiedi un numero allp'utente
#  - Se non è un numero mostra l'eerore

# %%
while True:
    try:
        num1=float(input("Inserisci un numero:"))
    except ValueError:
        print("Errore! Devi inserire un numero!")
    else:
        print("Hai inserito: ", num1)
# Out:
# Hai inserito:  1.5

# %% [markdown]
# ### Filippo:
# - Chiedi due numeri e dividi. Gestisci divizione usando (ZeroDivisionError) per gestire l'errore

# %%
while True:
    try:
        num1 = int(input("Inserisci il primo numero: "))
        num2 = int(input("Inserisci il secondo numero: "))
        if num1 == 0:
            raise ZeroDivisionError
        print(f"Hai inserito -> {num1} e {num2} pre la divizione")
        print("Il risultato della divisione è -> ", num1 / num2)
    except ZeroDivisionError:
        print("Errore! Inserisci un numero diverso da zero! 😤😤😤")
    
print("==================Fine programma! 🙂==================\n")
# Out:
# Hai inserito ->  5 2
# Il risultato della divisione è ->  2.5
# ==================Fine programma! 🙂==================

# %% [markdown]
# ### Ana:
# - Apri un file. Se non esiste, mostra un messaggio

# %%
import os


try:
    nome_arquivo = open("prodotto.csv", "r")
    # os.path.exists(nome_arquivo)
except:
    print("Attenzione: questo file non esiste")
else:
    print("Il file è salvato")
# Out:
# Attenzione: questo file non esiste

# %% [markdown]
# ### Brenda:
# - Chiedi due numeri e somma. Usa else nella try come visto prima

# %%
while True:
    try:
        num1 = float(input("Inserisci il primo numero: "))
        num2 = float(input("Inserisci il secondo numero: "))
    
    except ValueError:
        print("Errore! Riprova con dei numeri.")
    
    else:
        somma = num1 + num2
        print(f"La somma è: {somma}")
        break
# Out:
# Errore! Riprova con dei numeri.
# Errore! Riprova con dei numeri.
# Errore! Riprova con dei numeri.
# La somma è: 20.0

# %% [markdown]
# ### Mattia:
# - Mostra un messaggio finale dipendentemente dell'errore.

# %%
def sessione_umoristica():
    try:
        risposta = input("Vuoi sentire una barzelletta? Si o si?? ").strip().lower()
        
        if risposta == "si":
            print("Cosa fa una mucca sul divano? 🐮 Si STRAVACCA! 😂")
        
        elif risposta == "certo":
            print("Cosa fa una mucca sul divano? 🐮 Si STRAVACCA! 😂")

        elif risposta == "no":
            raise ValueError("L'utente ha rifiutato la barzelletta")
        
        elif risposta.isdigit():
            raise TypeError("L'utente ha inserito dei numeri invece di una risposta testuale")
        
        else:
            print("Eppure era una domanda semplice... 😅")
    
    except ValueError:
        print("Non sai cosa ti perdi... 😒")
    
    except TypeError:
        print("Scusa, non parlo il numerese... 😅")
    
    finally:
        print("Grazie per aver partecipato alla sessione di barzellette! 😄")

sessione_umoristica()
# Out:
# Cosa fa una mucca sul divano? 🐮 Si STRAVACCA! 😂
# Grazie per aver partecipato alla sessione di barzellette! 😄

# %% [markdown]
# ### Cristian:
# - Chiedi un indice e mostra l'elemento nella lista. except (ValueError, IndexError)

# %%
numero = [1, 2, 3, 4, 5, 6, 7]

try:
    chiedi = int(input("Inserisci un numero: "))
    elemento_trovato = numero[chiedi]
except ValueError:
    print("ERRORE ! Il numero non è valido\n")
except IndexError:
    print("ERRORE ! Il numero non è indicizzato\n")
else:
      print(f"Hai inserito l' indice: {chiedi}.\n L'elemento corrispondente è: {elemento_trovato}")
# Out:
# Hai inserito l' indice: 5.
#  L'elemento corrispondente è: 6

# %% [markdown]
# ### Giuseppe:
# - chiedi tre numeri e calcola la media

# %%
while True:
    try:
        num1 = int(input("Inserisci il primo numero: "))
        num2 = int(input("Inserisci il secondo numero: "))
        num3 = int(input("Inserisci il terzo numero: "))
        media = (num1 + num2 + num3) / 3

    except ValueError:
        print("Errore! Devi inserire un numero!")

    else:
        print("La media è:", media)
        break
# Out:
# La media è: 11.333333333333334
