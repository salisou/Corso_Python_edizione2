# %% [markdown]
# <h1>📊 INTRODUZIONE A PANDAS</h1>
#
# ## 🧠 Cos’è Pandas
#
# Pandas è una libreria Python che serve per:
# <ul>
#   <li>leggere dati</li>
#   <li>analizzarli</li>
#   <li>trasformarli</li>
# </ul>
#
# 👉 È come Excel, ma con il codice
#
# istallazione di pandas
# pip install pandas

# %%
print("Ciao mondo")
# Out:
# Ciao mondo
