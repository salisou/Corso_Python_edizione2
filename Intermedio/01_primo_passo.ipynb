# %% [markdown]
# ## 📊 INTRODUZIONE A PANDAS
#
# ### 🧠 Cos’è Pandas
#
# <div class="container mb-3">
#     <p><i>Pandas è una libreria Python che serve per:</i></p>
#     <ul>
#         <li>leggere dati</li>
#         <li>analizzarli</li>
#         <li>trasformarli</li>
#     </ul>
# </div>
#
#
#
#
# 👉 È come Excel, ma con il codice
#
# ### istallazione di pandas
# <ul>
#   <li>pip install pandas</li>
# </ul>

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print("Ciao Filippo, benvenuto nel mondo della programmazione Python!")
# Out:
# Ciao Filippo, benvenuto nel mondo della programmazione Python!

# %%
import pandas as pd

# Creazione del dataframe(dati) = dataset(Tabella)
data = {
    "nome": ["Filippo", "Salomon", "Asia", "Ana"],
    "cognome": ["Battaglia", "Rossi", "Verdi", "Neri"],
    "voto": [8, 10, 9, 7]
}

df = pd.DataFrame(data) # chiama pandas e crea un dataframe con i dati 

df
# Out:
#       nome    cognome  voto
# 0  Filippo  Battaglia     8
# 1  Salomon      Rossi    10
# 2     Asia      Verdi     9
# 3      Ana       Neri     7

# %% [markdown]
# Stampa in console del dataframe tipo csv

# %%
print(df)

# %% [markdown]
# Stampa la prima riga della tabella

# %%
df.head(1)

# %% [markdown]
# restituisce informazioni del dataframe

# %%
df.info()

# %% [markdown]
# restituisce le statistiche descrittive del dataframe

# %%
df.describe()

# %% [markdown]
# restituisece la lista dei nomi

# %%
df["nome"]

# %% [markdown]
# restituisece la lista dei nomi

# %%
df[["nome", "voto"]]
